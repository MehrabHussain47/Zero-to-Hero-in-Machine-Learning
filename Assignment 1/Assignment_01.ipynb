# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
temp = int(input("Enter current temperature(in celsius): "))

if temp < 10:
  print("It's too cold!")
elif temp >= 10 and temp <= 25:
  print("Tt's cool outside")
else:
  print("It's hot outside!")
# Out:
# Enter current temperature(in celsius): 23
# Tt's cool outside

# %% [markdown]
# ![Problem 2.PNG](data:image/png;base64,...)

# %%
account_balance = int(input("Enter the balance of the account: "))
withdraw = int(input("Enter the balance that you want to withdraw: "))

if account_balance >= withdraw:
  print("Transaction Successful")
else:
  print("Insufficient Balance")
# Out:
# Enter the balance of the account: 1000
# Enter the balance that you want to withdraw: 1000
# Transaction Successful

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
mark = int(input("Enter your number in exam: "))

if mark <= 100 and mark >= 90:
  print("A+")
elif mark <= 89 and mark >= 80:
  print("A")
elif mark <= 79 and mark >= 70:
  print("B")
elif mark <= 69 and mark >= 60:
  print("C")
elif mark <= 59 and mark >= 0:
  print("Fail")
else:
  print("Invalid number for grade.")
# Out:
# Enter your number in exam: 150
# Invalid number for grade.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
age = int(input("Enter your age: "))

if age < 5 and age >= 0:
  print("Free")
elif age <= 18 and age >= 5:
  print("50% Discount")
elif age >= 60:
  print("30% Discount")
elif age > 18 and age < 60:
  print("Full Price")
else:
  print("Invalid age for pricing")
# Out:
# Enter your age: -22
# Invalid age for pricing

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
bill = int(input("Enter total bill amount: "))

if bill > 1000:
  print("apply 10% discount")
elif bill <= 1000 and bill >= 0:
  print("no discount")
else:
  print("invalid amount for discount")
# Out:
# Enter total bill amount: 2000
# apply 10% discount

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
  print("Login Successful")
else:
  print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 12345
# Login Successful

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
traffic_light = input("Enter a colour: ")

if traffic_light == "red":
  print("Stop")
elif traffic_light == "yellow":
  print("Ready to go")
elif traffic_light == "green":
  print("Go")
else:
  print("Invalid color")
# Out:
# Enter a colour: blue
# Invalid color

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
year = int(input("Enter the year: "))

if (year % 400 == 0):
  print("Leap Year")
elif (year % 4 == 0 and year % 100 != 0):
  print("Leap Year")
else:
  print("Not a Leap Year")
# Out:
# Enter the year: 2026
# Not a Leap Year

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
age = int(input("Enter your age: "))
qualification = input("Enter your educational qualification: ")

if age >= 18 and qualification == "graduate":
  print("Eligible for Job")
else:
  print("Not Eligible")
# Out:
# Enter your age: 19
# Enter your educational qualification: graduate
# Eligible for Job

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
consumed_unit = int(input("Enter the number of units: "))

if consumed_unit <= 100 and consumed_unit >= 0:
  bill = 5 * consumed_unit
  print(f"Total payable amount = {bill} BDT")
elif consumed_unit > 100 and consumed_unit <= 200:
  bill = 7 * consumed_unit
  print(f"Total payable amount = {bill} BDT")
elif consumed_unit > 200:
  bill = 10 * consumed_unit
  print(f"Total payable amount = {bill} BDT")
else:
  print("Invalid amount for pay")
# Out:
# Enter the number of units: 201
# Total payable amount = 2010 BDT
